# %% [markdown]
# # Notebook Title

# %% [markdown]
# ## Setup Python and R environment
# you can ignore this section

# %%
# %load_ext rpy2.ipython
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline  
from matplotlib import rcParams
rcParams['figure.figsize'] = (16, 100)

import warnings
from rpy2.rinterface import RRuntimeWarning
warnings.filterwarnings("ignore") # Ignore all warnings
# warnings.filterwarnings("ignore", category=RRuntimeWarning) # Show some warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, HTML
# Out:
# During startup - Warning messages:
# 1: Setting LC_COLLATE failed, using "C"
# 2: Setting LC_TIME failed, using "C"
# 3: Setting LC_MESSAGES failed, using "C"
# 4: Setting LC_MONETARY failed, using "C"

# %%
# %%javascript
# // Disable auto-scrolling
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
# %%R
#
# # My commonly used R imports
#
# require('tidyverse')
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: tidyverse

# %% [markdown]
# ## 👉 download your data
#
# You can write code here to download your dataset. Or if you already have it, just leave the URL in the comments and just load it into a pandas or R (or both) dataframe.

# %%
import pandas as pd

# %%
df = pd.read_csv('Active_Tobacco_Retailer_Map.csv')
df
# Out:
#       LOCAL HEALTH UNIT                     OPERATION NAME              CITY  \
# 0               CLINTON                        GRAND UNION              PERU
# 1              DUTCHESS                     CHESTNUT MARTS           WASSAIC
# 2                   NYC                      2918 GAS CORP             BRONX
# 3                   NYC                     MAHANT 385 INC          NEW YORK
# 4                   NYC                   SHISHA KING CORP          BROOKLYN
# ...                 ...                                ...               ...
# 16754        CHAUTAUQUA                        MATT'S NEWS           DUNKIRK
# 16755               NYC   EASTSIDE CONVENIENCE CORPORATION          NEW YORK
# 16756               NYC                DOPEBOYS EXOTIC INC          BROOKLYN
# 16757    GLENS FALLS DO                STEWART'S SHOP #215       FORT EDWARD
# 16758               NYC  A & S ROCKAWAY DELI GROCERY CORP.  SOUTH OZONE PARK
#
#       STATE      ZIP MUNICIPALITY         COUNTY          VENDOR TYPE  \
# 0        NY  12972.0         PERU        CLINTON  GROCERY SUPERMARKET
# 1        NY  12592.0       AMENIA       DUTCHESS      CONVENIENCE/GAS
# 2        NY  10469.0        BRONX  NEW YORK CITY                OTHER
# 3        NY  10013.0    MANHATTAN  NEW YORK CITY       TOBACCO RETAIL
# 4        NY  11207.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# ...     ...      ...          ...            ...                  ...
# 16754    NY  14048.0      DUNKIRK     CHAUTAUQUA    CONVENIENCE STORE
# 16755    NY  10128.0    MANHATTAN  NEW YORK CITY    CONVENIENCE STORE
# 16756    NY  11210.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 16757    NY  12828.0  FORT EDWARD     WASHINGTON    CONVENIENCE STORE
# 16758    NY  11420.0       QUEENS  NEW YORK CITY  GROCERY SUPERMARKET
#
#       CREATION DATE                                           LOCATION
# 0        07/10/2023  2 GORMAN WAY\nPERU, NY 12972\n(44.577028232, -...
# 1        07/10/2023  3997 ROUTE 22\nWASSAIC, NY 12592\n(41.79081480...
# 2        07/10/2023  2918 BOSTON ROAD\nBRONX, NY 10469\n(40.8680588...
# 3        07/10/2023  385 CANAL STREET\nNEW YORK, NY 10013\n(40.7216...
# 4        07/10/2023  656 SUTTER AVENUE\nBROOKLYN, NY 11207\n(40.669...
# ...             ...                                                ...
# 16754    07/10/2023  93 EAST THIRD STREET\nDUNKIRK, NY 14048\n(42.4...
# 16755    07/10/2023  1726 1ST  AVENUE\nNEW YORK, NY 10128\n(40.7790...
# 16756    07/10/2023  1437 FLATBUSH AVENUE\nBROOKLYN, NY 11210\n(40....
# 16757    07/10/2023  107 BROADWAY\nFORT EDWARD, NY 12828\n(43.26720...
# 16758    07/10/2023  123-36 ROCKAWAY BOULEVARD\nSOUTH OZONE PARK, N...
#
# [16759 rows x 10 columns]

# %% [markdown]
# ## 👉 convert addresses --> lat/long
#
# See the [census-examples](https://github.com/data4news/census-examples) repository for examples. If you need help, try asking in the class slack channel. Chances are someone in the class is struggling with the same problem as you are so we might as well all learn together in the same slack channel!

# %%
import re

df_new = df

# Your provided regular expression pattern
regex_pattern = r'\(([-\d\.]+), ?([-\d\.]+)\)'

# Extract the coordinates using the regular expression and assign them to 'LAT' and 'LONG' columns
df_new[['LAT', 'LONG']] = df_new['LOCATION'].str.extract(regex_pattern, expand=True)

df_new
# Out:
#       LOCAL HEALTH UNIT                     OPERATION NAME              CITY  \
# 0               CLINTON                        GRAND UNION              PERU
# 1              DUTCHESS                     CHESTNUT MARTS           WASSAIC
# 2                   NYC                      2918 GAS CORP             BRONX
# 3                   NYC                     MAHANT 385 INC          NEW YORK
# 4                   NYC                   SHISHA KING CORP          BROOKLYN
# ...                 ...                                ...               ...
# 16754        CHAUTAUQUA                        MATT'S NEWS           DUNKIRK
# 16755               NYC   EASTSIDE CONVENIENCE CORPORATION          NEW YORK
# 16756               NYC                DOPEBOYS EXOTIC INC          BROOKLYN
# 16757    GLENS FALLS DO                STEWART'S SHOP #215       FORT EDWARD
# 16758               NYC  A & S ROCKAWAY DELI GROCERY CORP.  SOUTH OZONE PARK
#
#       STATE      ZIP MUNICIPALITY         COUNTY          VENDOR TYPE  \
# 0        NY  12972.0         PERU        CLINTON  GROCERY SUPERMARKET
# 1        NY  12592.0       AMENIA       DUTCHESS      CONVENIENCE/GAS
# 2        NY  10469.0        BRONX  NEW YORK CITY                OTHER
# 3        NY  10013.0    MANHATTAN  NEW YORK CITY       TOBACCO RETAIL
# 4        NY  11207.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# ...     ...      ...          ...            ...                  ...
# 16754    NY  14048.0      DUNKIRK     CHAUTAUQUA    CONVENIENCE STORE
# 16755    NY  10128.0    MANHATTAN  NEW YORK CITY    CONVENIENCE STORE
# 16756    NY  11210.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 16757    NY  12828.0  FORT EDWARD     WASHINGTON    CONVENIENCE STORE
# 16758    NY  11420.0       QUEENS  NEW YORK CITY  GROCERY SUPERMARKET
#
#       CREATION DATE                                           LOCATION  \
# 0        07/10/2023  2 GORMAN WAY\nPERU, NY 12972\n(44.577028232, -...
# 1        07/10/2023  3997 ROUTE 22\nWASSAIC, NY 12592\n(41.79081480...
# 2        07/10/2023  2918 BOSTON ROAD\nBRONX, NY 10469\n(40.8680588...
# 3        07/10/2023  385 CANAL STREET\nNEW YORK, NY 10013\n(40.7216...
# 4        07/10/2023  656 SUTTER AVENUE\nBROOKLYN, NY 11207\n(40.669...
# ...             ...                                                ...
# 16754    07/10/2023  93 EAST THIRD STREET\nDUNKIRK, NY 14048\n(42.4...
# 16755    07/10/2023  1726 1ST  AVENUE\nNEW YORK, NY 10128\n(40.7790...
# 16756    07/10/2023  1437 FLATBUSH AVENUE\nBROOKLYN, NY 11210\n(40....
# 16757    07/10/2023  107 BROADWAY\nFORT EDWARD, NY 12828\n(43.26720...
# 16758    07/10/2023  123-36 ROCKAWAY BOULEVARD\nSOUTH OZONE PARK, N...
#
#                      LAT                LONG
# 0           44.577028232       -73.525724408
# 1           41.790814801       -73.553360632
# 2           40.868058834       -73.858776062
# 3           40.721667889       -74.004767693
# 4           40.669383086       -73.894472157
# ...                  ...                 ...
# 16754       42.485506391       -79.329351149
# 16755       40.779000651       -73.947582326
# 16756       40.635653511       -73.950397388
# 16757  43.26720959700003  -73.58553800399994
# 16758        40.67530578       -73.813723332
#
# [16759 rows x 12 columns]

# %%
df_new['LOCATION'] = df_new['LOCATION'].str.replace('\n', ' ')
df_new
# Out:
#       LOCAL HEALTH UNIT                     OPERATION NAME              CITY  \
# 0               CLINTON                        GRAND UNION              PERU
# 1              DUTCHESS                     CHESTNUT MARTS           WASSAIC
# 2                   NYC                      2918 GAS CORP             BRONX
# 3                   NYC                     MAHANT 385 INC          NEW YORK
# 4                   NYC                   SHISHA KING CORP          BROOKLYN
# ...                 ...                                ...               ...
# 16754        CHAUTAUQUA                        MATT'S NEWS           DUNKIRK
# 16755               NYC   EASTSIDE CONVENIENCE CORPORATION          NEW YORK
# 16756               NYC                DOPEBOYS EXOTIC INC          BROOKLYN
# 16757    GLENS FALLS DO                STEWART'S SHOP #215       FORT EDWARD
# 16758               NYC  A & S ROCKAWAY DELI GROCERY CORP.  SOUTH OZONE PARK
#
#       STATE      ZIP MUNICIPALITY         COUNTY          VENDOR TYPE  \
# 0        NY  12972.0         PERU        CLINTON  GROCERY SUPERMARKET
# 1        NY  12592.0       AMENIA       DUTCHESS      CONVENIENCE/GAS
# 2        NY  10469.0        BRONX  NEW YORK CITY                OTHER
# 3        NY  10013.0    MANHATTAN  NEW YORK CITY       TOBACCO RETAIL
# 4        NY  11207.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# ...     ...      ...          ...            ...                  ...
# 16754    NY  14048.0      DUNKIRK     CHAUTAUQUA    CONVENIENCE STORE
# 16755    NY  10128.0    MANHATTAN  NEW YORK CITY    CONVENIENCE STORE
# 16756    NY  11210.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 16757    NY  12828.0  FORT EDWARD     WASHINGTON    CONVENIENCE STORE
# 16758    NY  11420.0       QUEENS  NEW YORK CITY  GROCERY SUPERMARKET
#
#       CREATION DATE                                           LOCATION  \
# 0        07/10/2023  2 GORMAN WAY PERU, NY 12972 (44.577028232, -73...
# 1        07/10/2023  3997 ROUTE 22 WASSAIC, NY 12592 (41.790814801,...
# 2        07/10/2023  2918 BOSTON ROAD BRONX, NY 10469 (40.868058834...
# 3        07/10/2023  385 CANAL STREET NEW YORK, NY 10013 (40.721667...
# 4        07/10/2023  656 SUTTER AVENUE BROOKLYN, NY 11207 (40.66938...
# ...             ...                                                ...
# 16754    07/10/2023  93 EAST THIRD STREET DUNKIRK, NY 14048 (42.485...
# 16755    07/10/2023  1726 1ST  AVENUE NEW YORK, NY 10128 (40.779000...
# 16756    07/10/2023  1437 FLATBUSH AVENUE BROOKLYN, NY 11210 (40.63...
# 16757    07/10/2023  107 BROADWAY FORT EDWARD, NY 12828 (43.2672095...
# 16758    07/10/2023  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
#                      LAT                LONG
# 0           44.577028232       -73.525724408
# 1           41.790814801       -73.553360632
# 2           40.868058834       -73.858776062
# 3           40.721667889       -74.004767693
# 4           40.669383086       -73.894472157
# ...                  ...                 ...
# 16754       42.485506391       -79.329351149
# 16755       40.779000651       -73.947582326
# 16756       40.635653511       -73.950397388
# 16757  43.26720959700003  -73.58553800399994
# 16758        40.67530578       -73.813723332
#
# [16759 rows x 12 columns]

# %%
# Adjusted regular expression pattern to match the address part
regex_pattern = r'(.+)\('

# Extract the address using the regular expression and assign it to the 'ADDRESS' column
df_new['ADDRESS'] = df_new['LOCATION'].str.extract(regex_pattern, expand=True)

df_new
# Out:
#       LOCAL HEALTH UNIT                     OPERATION NAME              CITY  \
# 0               CLINTON                        GRAND UNION              PERU
# 1              DUTCHESS                     CHESTNUT MARTS           WASSAIC
# 2                   NYC                      2918 GAS CORP             BRONX
# 3                   NYC                     MAHANT 385 INC          NEW YORK
# 4                   NYC                   SHISHA KING CORP          BROOKLYN
# ...                 ...                                ...               ...
# 16754        CHAUTAUQUA                        MATT'S NEWS           DUNKIRK
# 16755               NYC   EASTSIDE CONVENIENCE CORPORATION          NEW YORK
# 16756               NYC                DOPEBOYS EXOTIC INC          BROOKLYN
# 16757    GLENS FALLS DO                STEWART'S SHOP #215       FORT EDWARD
# 16758               NYC  A & S ROCKAWAY DELI GROCERY CORP.  SOUTH OZONE PARK
#
#       STATE      ZIP MUNICIPALITY         COUNTY          VENDOR TYPE  \
# 0        NY  12972.0         PERU        CLINTON  GROCERY SUPERMARKET
# 1        NY  12592.0       AMENIA       DUTCHESS      CONVENIENCE/GAS
# 2        NY  10469.0        BRONX  NEW YORK CITY                OTHER
# 3        NY  10013.0    MANHATTAN  NEW YORK CITY       TOBACCO RETAIL
# 4        NY  11207.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# ...     ...      ...          ...            ...                  ...
# 16754    NY  14048.0      DUNKIRK     CHAUTAUQUA    CONVENIENCE STORE
# 16755    NY  10128.0    MANHATTAN  NEW YORK CITY    CONVENIENCE STORE
# 16756    NY  11210.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 16757    NY  12828.0  FORT EDWARD     WASHINGTON    CONVENIENCE STORE
# 16758    NY  11420.0       QUEENS  NEW YORK CITY  GROCERY SUPERMARKET
#
#       CREATION DATE                                           LOCATION  \
# 0        07/10/2023  2 GORMAN WAY PERU, NY 12972 (44.577028232, -73...
# 1        07/10/2023  3997 ROUTE 22 WASSAIC, NY 12592 (41.790814801,...
# 2        07/10/2023  2918 BOSTON ROAD BRONX, NY 10469 (40.868058834...
# 3        07/10/2023  385 CANAL STREET NEW YORK, NY 10013 (40.721667...
# 4        07/10/2023  656 SUTTER AVENUE BROOKLYN, NY 11207 (40.66938...
# ...             ...                                                ...
# 16754    07/10/2023  93 EAST THIRD STREET DUNKIRK, NY 14048 (42.485...
# 16755    07/10/2023  1726 1ST  AVENUE NEW YORK, NY 10128 (40.779000...
# 16756    07/10/2023  1437 FLATBUSH AVENUE BROOKLYN, NY 11210 (40.63...
# 16757    07/10/2023  107 BROADWAY FORT EDWARD, NY 12828 (43.2672095...
# 16758    07/10/2023  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
#                      LAT                LONG  \
# 0           44.577028232       -73.525724408
# 1           41.790814801       -73.553360632
# 2           40.868058834       -73.858776062
# 3           40.721667889       -74.004767693
# 4           40.669383086       -73.894472157
# ...                  ...                 ...
# 16754       42.485506391       -79.329351149
# 16755       40.779000651       -73.947582326
# 16756       40.635653511       -73.950397388
# 16757  43.26720959700003  -73.58553800399994
# 16758        40.67530578       -73.813723332
#
#                                                  ADDRESS
# 0                           2 GORMAN WAY PERU, NY 12972
# 1                       3997 ROUTE 22 WASSAIC, NY 12592
# 2                      2918 BOSTON ROAD BRONX, NY 10469
# 3                   385 CANAL STREET NEW YORK, NY 10013
# 4                  656 SUTTER AVENUE BROOKLYN, NY 11207
# ...                                                  ...
# 16754            93 EAST THIRD STREET DUNKIRK, NY 14048
# 16755               1726 1ST  AVENUE NEW YORK, NY 10128
# 16756           1437 FLATBUSH AVENUE BROOKLYN, NY 11210
# 16757                107 BROADWAY FORT EDWARD, NY 12828
# 16758  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
# [16759 rows x 13 columns]

# %%
import re  # Ensure the 're' module is imported

# Filter df_new by municipality for NEW YORK, BROOKLYN, BRONX, QUEENS, STATEN ISLAND
# Setting na=False makes the condition False for NaN values in 'MUNICIPALITY'
df_new = df_new[df_new['MUNICIPALITY'].str.contains('NEW YORK|BROOKLYN|BRONX|QUEENS|STATEN ISLAND', flags=re.I, regex=True, na=False)]

df_new
# Out:
#       LOCAL HEALTH UNIT                     OPERATION NAME              CITY  \
# 2                   NYC                      2918 GAS CORP             BRONX
# 4                   NYC                   SHISHA KING CORP          BROOKLYN
# 5                   NYC                TUNI'S SERVICE CORP          BROOKLYN
# 6                   NYC                  VISHWA NEWS, INC.          BROOKLYN
# 13                  NYC                JAMAST HOLDING CORP          FLUSHING
# ...                 ...                                ...               ...
# 16738               NYC                   BULLPEN DELI INC             BRONX
# 16748               NYC                  HI MANGO 1055 INC          BROOKLYN
# 16753               NYC           GREEN GARDEN 1 DELI CORP          BROOKLYN
# 16756               NYC                DOPEBOYS EXOTIC INC          BROOKLYN
# 16758               NYC  A & S ROCKAWAY DELI GROCERY CORP.  SOUTH OZONE PARK
#
#       STATE      ZIP MUNICIPALITY         COUNTY          VENDOR TYPE  \
# 2        NY  10469.0        BRONX  NEW YORK CITY                OTHER
# 4        NY  11207.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 5        NY  11215.0     BROOKLYN  NEW YORK CITY    CONVENIENCE STORE
# 6        NY  11201.0     BROOKLYN  NEW YORK CITY                STAND
# 13       NY  11358.0       QUEENS  NEW YORK CITY    CONVENIENCE STORE
# ...     ...      ...          ...            ...                  ...
# 16738    NY  10451.0        BRONX  NEW YORK CITY  GROCERY SUPERMARKET
# 16748    NY  11237.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 16753    NY  11229.0     BROOKLYN  NEW YORK CITY    CONVENIENCE STORE
# 16756    NY  11210.0     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 16758    NY  11420.0       QUEENS  NEW YORK CITY  GROCERY SUPERMARKET
#
#       CREATION DATE                                           LOCATION  \
# 2        07/10/2023  2918 BOSTON ROAD BRONX, NY 10469 (40.868058834...
# 4        07/10/2023  656 SUTTER AVENUE BROOKLYN, NY 11207 (40.66938...
# 5        07/10/2023  306 18TH STREET BROOKLYN, NY 11215 (40.6617226...
# 6        07/10/2023  17 BOND STREET BROOKLYN, NY 11201 (40.68917313...
# 13       07/10/2023  161-17 29TH AVENUE FLUSHING, NY 11358 (40.7714...
# ...             ...                                                ...
# 16738    07/10/2023  66 EAST 161ST STREET BRONX, NY 10451 (40.82737...
# 16748    07/10/2023  1055 FLUSHING AVENUE BROOKLYN, NY 11237 (40.70...
# 16753    07/10/2023  2801 NOSTRAND AVENUE BROOKLYN, NY 11229 (40.61...
# 16756    07/10/2023  1437 FLATBUSH AVENUE BROOKLYN, NY 11210 (40.63...
# 16758    07/10/2023  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
#                 LAT           LONG  \
# 2      40.868058834  -73.858776062
# 4      40.669383086  -73.894472157
# 5      40.661722613  -73.989687559
# 6      40.689173136  -73.983153782
# 13     40.771400067  -73.802775896
# ...             ...            ...
# 16738  40.827371567  -73.925433985
# 16748  40.704307082  -73.930115445
# 16753  40.615751653  -73.944714386
# 16756  40.635653511  -73.950397388
# 16758   40.67530578  -73.813723332
#
#                                                  ADDRESS
# 2                      2918 BOSTON ROAD BRONX, NY 10469
# 4                  656 SUTTER AVENUE BROOKLYN, NY 11207
# 5                    306 18TH STREET BROOKLYN, NY 11215
# 6                     17 BOND STREET BROOKLYN, NY 11201
# 13                161-17 29TH AVENUE FLUSHING, NY 11358
# ...                                                  ...
# 16738              66 EAST 161ST STREET BRONX, NY 10451
# 16748           1055 FLUSHING AVENUE BROOKLYN, NY 11237
# 16753           2801 NOSTRAND AVENUE BROOKLYN, NY 11229
# 16756           1437 FLATBUSH AVENUE BROOKLYN, NY 11210
# 16758  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
# [5469 rows x 13 columns]

# %%
#export df_new as a csv
df_new.to_csv('active_tobacco_retailer_map_correct_cleaned.csv', index=False)
print('done')
# Out:
# done

# %% [markdown]
# ## 👉 convert lat/long to census geography codes
#
# (like 'GEOID', 'STATE', 'COUNTY', 'TRACT', 'BLOCK', etc...)
#
# Same note as above, see [census-examples](https://github.com/data4news/census-examples) repository for examples or ask in the class slack channel if stuck.

# %%
# %%R
#
# library(tigris)
# library(tidyverse)

# %%
# %%R
#
# # Load the cleaned data
# df <- read.csv('active_tobacco_retailer_map_correct_cleaned.csv')

# %%
# %%R
#
# #filter df to just the first 10 rows and pass it to a new df_top_10
# df_top_10 <- df %>% head(10)

# %%
# %%R
#
# coord <- df_top_10
#
# coord$census_code <- apply(coord, 1, function(row) call_geolocator_latlon(row['LAT'], row['LONG']))
#
# coord
# Out:
#    LOCAL.HEALTH.UNIT      OPERATION.NAME      CITY STATE   ZIP MUNICIPALITY
# 1            CLINTON         GRAND UNION      PERU    NY 12972         PERU
# 2           DUTCHESS      CHESTNUT MARTS   WASSAIC    NY 12592       AMENIA
# 3                NYC       2918 GAS CORP     BRONX    NY 10469        BRONX
# 4                NYC      MAHANT 385 INC  NEW YORK    NY 10013    MANHATTAN
# 5                NYC    SHISHA KING CORP  BROOKLYN    NY 11207     BROOKLYN
# 6                NYC TUNI'S SERVICE CORP  BROOKLYN    NY 11215     BROOKLYN
# 7                NYC   VISHWA NEWS, INC.  BROOKLYN    NY 11201     BROOKLYN
# 8             PUTNAM              76 GAS    CARMEL    NY 10512         KENT
# 9            SUFFOLK               MOBIL PATCHOGUE    NY   117   BROOKHAVEN
# 10           SUFFOLK      THE WHALE BONE              NY    NA  SOUTHAMPTON
#           COUNTY         VENDOR.TYPE CREATION.DATE
# 1        CLINTON GROCERY SUPERMARKET    07/10/2023
# 2       DUTCHESS     CONVENIENCE/GAS    07/10/2023
# 3  NEW YORK CITY               OTHER    07/10/2023
# 4  NEW YORK CITY      TOBACCO RETAIL    07/10/2023
# 5  NEW YORK CITY GROCERY SUPERMARKET    07/10/2023
# 6  NEW YORK CITY   CONVENIENCE STORE    07/10/2023
# 7  NEW YORK CITY               STAND    07/10/2023
# 8         PUTNAM         GAS STATION    07/10/2023
# 9        SUFFOLK         GAS STATION    07/10/2023
# 10       SUFFOLK               OTHER    07/10/2023
#                                                              LOCATION      LAT
# 1           2 GORMAN WAY PERU, NY 12972 (44.577028232, -73.525724408) 44.57703
# 2       3997 ROUTE 22 WASSAIC, NY 12592 (41.790814801, -73.553360632) 41.79081
# 3      2918 BOSTON ROAD BRONX, NY 10469 (40.868058834, -73.858776062) 40.86806
# 4   385 CANAL STREET NEW YORK, NY 10013 (40.721667889, -74.004767693) 40.72167
# 5  656 SUTTER AVENUE BROOKLYN, NY 11207 (40.669383086, -73.894472157) 40.66938
# 6    306 18TH STREET BROOKLYN, NY 11215 (40.661722613, -73.989687559) 40.66172
# 7     17 BOND STREET BROOKLYN, NY 11201 (40.689173136, -73.983153782) 40.68917
# 8       2 TOWNERS ROAD CARMEL, NY 10512 (41.449989058, -73.671833805) 41.44999
# 9       451 W MAIN ST PATCHOGUE, NY 117 (40.760975695, -73.029896708) 40.76098
# 10                    3495 NOYAC RD, NY (40.995954451, -72.339820222) 40.99595
#         LONG                               ADDRESS     census_code
# 1  -73.52572          2 GORMAN WAY PERU, NY 12972  360191019013005
# 2  -73.55336      3997 ROUTE 22 WASSAIC, NY 12592  360270100002009
# 3  -73.85878     2918 BOSTON ROAD BRONX, NY 10469  360050342002008
# 4  -74.00477  385 CANAL STREET NEW YORK, NY 10013  360610047002004
# 5  -73.89447 656 SUTTER AVENUE BROOKLYN, NY 11207  360471156001001
# 6  -73.98969   306 18TH STREET BROOKLYN, NY 11215  360470143002001
# 7  -73.98315    17 BOND STREET BROOKLYN, NY 11201  360470037001002
# 8  -73.67183      2 TOWNERS ROAD CARMEL, NY 10512  360790104003000
# 9  -73.02990      451 W MAIN ST PATCHOGUE, NY 117  361031589011012
# 10 -72.33982                    3495 NOYAC RD, NY  361031907111050

# %%
# %%R
#
# coord$census_tract <- substr(coord$census_code, 6, 11)
# coord$census_tract
# Out:
#  [1] "101901" "010000" "034200" "004700" "115600" "014300" "003700" "010400"
#  [9] "158901" "190711"

# %%
# %%R
#
# coord$census_code
# Out:
#  [1] "360191019013005" "360270100002009" "360050342002008" "360610047002004"
#  [5] "360471156001001" "360470143002001" "360470037001002" "360790104003000"
#  [9] "361031589011012" "361031907111050"

# %% [markdown]
# # Running tigris on the actual df

# %%
# %%R
#
# coord <- df
#
# coord$census_code <- apply(coord, 1, function(row) call_geolocator_latlon(row['LAT'], row['LONG']))
#
# coord$census_code %>% head(10)
# Out:
#  [1] "360050342002008" "360471156001001" "360470143002001" "360470037001002"
#  [5] "360811059004015" "360470122001000" "360470520001001" "360610111001000"
#  [9] "360470453001010" "360050297001005"

# %%
# %%R
#
# coord$census_tract <- substr(coord$census_code, 6, 11)
# coord$census_tract %>% head(10)
# Out:
#  [1] "034200" "115600" "014300" "003700" "105900" "012200" "052000" "011100"
#  [9] "045300" "029700"

# %% [markdown]
# ## 👉 Output Data
#
# Output your dataframe containing your data and the Census connector codes (like tract, block, etc...).

# %%
# %%R
#
# #export coord as csv in R
# write.csv(coord, 'active_tobacco_retailer_map_correct_cleaned_with_census.csv', row.names=FALSE)

# %%
# Checking it in Python

df_with_census = pd.read_csv('active_tobacco_retailer_map_correct_cleaned_with_census.csv')
df_with_census
# Out:
#      LOCAL.HEALTH.UNIT                     OPERATION.NAME              CITY  \
# 0                  NYC                      2918 GAS CORP             BRONX
# 1                  NYC                   SHISHA KING CORP          BROOKLYN
# 2                  NYC                TUNI'S SERVICE CORP          BROOKLYN
# 3                  NYC                  VISHWA NEWS, INC.          BROOKLYN
# 4                  NYC                JAMAST HOLDING CORP          FLUSHING
# ...                ...                                ...               ...
# 5464               NYC                   BULLPEN DELI INC             BRONX
# 5465               NYC                  HI MANGO 1055 INC          BROOKLYN
# 5466               NYC           GREEN GARDEN 1 DELI CORP          BROOKLYN
# 5467               NYC                DOPEBOYS EXOTIC INC          BROOKLYN
# 5468               NYC  A & S ROCKAWAY DELI GROCERY CORP.  SOUTH OZONE PARK
#
#      STATE    ZIP MUNICIPALITY         COUNTY          VENDOR.TYPE  \
# 0       NY  10469        BRONX  NEW YORK CITY                OTHER
# 1       NY  11207     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 2       NY  11215     BROOKLYN  NEW YORK CITY    CONVENIENCE STORE
# 3       NY  11201     BROOKLYN  NEW YORK CITY                STAND
# 4       NY  11358       QUEENS  NEW YORK CITY    CONVENIENCE STORE
# ...    ...    ...          ...            ...                  ...
# 5464    NY  10451        BRONX  NEW YORK CITY  GROCERY SUPERMARKET
# 5465    NY  11237     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 5466    NY  11229     BROOKLYN  NEW YORK CITY    CONVENIENCE STORE
# 5467    NY  11210     BROOKLYN  NEW YORK CITY  GROCERY SUPERMARKET
# 5468    NY  11420       QUEENS  NEW YORK CITY  GROCERY SUPERMARKET
#
#      CREATION.DATE                                           LOCATION  \
# 0       07/10/2023  2918 BOSTON ROAD BRONX, NY 10469 (40.868058834...
# 1       07/10/2023  656 SUTTER AVENUE BROOKLYN, NY 11207 (40.66938...
# 2       07/10/2023  306 18TH STREET BROOKLYN, NY 11215 (40.6617226...
# 3       07/10/2023  17 BOND STREET BROOKLYN, NY 11201 (40.68917313...
# 4       07/10/2023  161-17 29TH AVENUE FLUSHING, NY 11358 (40.7714...
# ...            ...                                                ...
# 5464    07/10/2023  66 EAST 161ST STREET BRONX, NY 10451 (40.82737...
# 5465    07/10/2023  1055 FLUSHING AVENUE BROOKLYN, NY 11237 (40.70...
# 5466    07/10/2023  2801 NOSTRAND AVENUE BROOKLYN, NY 11229 (40.61...
# 5467    07/10/2023  1437 FLATBUSH AVENUE BROOKLYN, NY 11210 (40.63...
# 5468    07/10/2023  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
#             LAT       LONG                                            ADDRESS  \
# 0     40.868059 -73.858776                  2918 BOSTON ROAD BRONX, NY 10469
# 1     40.669383 -73.894472              656 SUTTER AVENUE BROOKLYN, NY 11207
# 2     40.661723 -73.989688                306 18TH STREET BROOKLYN, NY 11215
# 3     40.689173 -73.983154                 17 BOND STREET BROOKLYN, NY 11201
# 4     40.771400 -73.802776             161-17 29TH AVENUE FLUSHING, NY 11358
# ...         ...        ...                                                ...
# 5464  40.827372 -73.925434              66 EAST 161ST STREET BRONX, NY 10451
# 5465  40.704307 -73.930115           1055 FLUSHING AVENUE BROOKLYN, NY 11237
# 5466  40.615752 -73.944714           2801 NOSTRAND AVENUE BROOKLYN, NY 11229
# 5467  40.635654 -73.950397           1437 FLATBUSH AVENUE BROOKLYN, NY 11210
# 5468  40.675306 -73.813723  123-36 ROCKAWAY BOULEVARD SOUTH OZONE PARK, NY...
#
#           census_code  census_tract
# 0     360050342002008         34200
# 1     360471156001001        115600
# 2     360470143002001         14300
# 3     360470037001002          3700
# 4     360811059004015        105900
# ...               ...           ...
# 5464  360050063011003          6301
# 5465  360470453002013         45300
# 5466  360470644001002         64400
# 5467  360470786011002         78601
# 5468  360810840002000         84000
#
# [5469 rows x 15 columns]
